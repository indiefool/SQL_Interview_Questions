# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreekar-Kandhadai/SQL_Interview_Questions/blob/main/Singly_Linked_List/Adding_two_Linked_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:

  def __init__(self,value):
    self.value=value
    self.next=None

  def add_lists(self,l1,l2):

    dummy=Solution(0)

    current=dummy

    carry=0

    while l1 or l2 or carry:

      val1= l1.value if l1 else 0
      val2=l2.value if l2 else 0

      total=val1+val2+carry
      carry=total//10

      current.next=Solution(total%10)
      current=current.next

      l1=l1.next if l1 else None
      l2=l2.next if l2 else None

    return dummy.next

  def print_lists(self,head):

    while head:
      print(head.value,end=" -> ")
      head=head.next

    print("None")



l1=Solution(2)
l1.next=Solution(4)
l1.next.next=Solution(3)

l2=Solution(5)
l2.next=Solution(6)
l2.next.next=Solution(4)

s=Solution(0)
result=s.add_lists(l1,l2)

s.print_lists(result)
# Out:
# 7 -> 0 -> 8 -> None
